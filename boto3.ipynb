# %%
import boto3
import pandas as pd
import json

# %%
s3 = boto3.client('s3', region_name='us-east-1', 
                         aws_access_key_id='AKIA57PQ63UP7JT2KMVE', aws_secret_access_key='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')

# %%
bucket = s3.list_objects(Bucket='udacity-dend', Delimiter='/', Prefix='')

# %%
bucket
# Out:
# {'ResponseMetadata': {'RequestId': 'DQBQ8FXPVCGFAZ03',
#   'HostId': '5xU8o+yvCRjrnhAtUn7pIeVcxWiyKQv8w4z4pI3jrnNBMfogI4i7hsuHF7ZdWB5YTCTfg0TwW+U=',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': '5xU8o+yvCRjrnhAtUn7pIeVcxWiyKQv8w4z4pI3jrnNBMfogI4i7hsuHF7ZdWB5YTCTfg0TwW+U=',
#    'x-amz-request-id': 'DQBQ8FXPVCGFAZ03',
#    'date': 'Fri, 09 Jul 2021 09:59:33 GMT',
#    'x-amz-bucket-region': 'us-west-2',
#    'content-type': 'application/xml',
#    'transfer-encoding': 'chunked',
#    'server': 'AmazonS3'},
#   'RetryAttempts': 0},
#  'IsTruncated': False,
#  'Marker': '',
#  'Contents': [{'Key': 'log_json_path.json',
#    'LastModified': datetime.datetime(2019, 4, 2, 16, 58, 44, tzinfo=tzlocal()),
#    'ETag': '"6ee138e5504cffd12cded1323dfbd6a4"',
#    'Size': 456,
#    'StorageClass': 'STANDARD'}],
#  'Name': 'udacity-dend',
#  'Prefix': '',
#  'Delimiter': '/',
#  'MaxKeys': 1000,
#  'CommonPrefixes': [{'Prefix': 'data-pipelines/'},
#   {'Prefix': 'log-data/'},
# ...

# %%
pd.DataFrame(objects['Contents'])
# Out:
#                                       ETag  \
# 0       "d41d8cd98f00b204e9800998ecf8427e"
# 1    "0469e599b0f3b72bc93673be52d7b2d0-24"
# 2       "3d59e5e167523d49200c7a603b6970b1"
# 3       "6276f29cea4a91d915600016c1a789c7"
# 4       "6f61ca42deffd18b155210e449eb0e11"
# 5       "0a594c98d7b4a8be03e0d4997a94ba79"
# 6       "cf8f2e5317e0eb7b7cc36169d13b6812"
# 7       "7a2847dad9275a3abbdd9bd6408d039d"
# 8       "f5e02484f19af296994b25aee73be5b4"
# 9       "c8b9d0927d21e8a453c831a77e1a9584"
# 10      "e65690f59451aaa8736ddc42f641c369"
# 11      "127c64c276a2928f07eadad746759c9c"
# 12      "3b1bfa3b63ee5ca6aac0328183c68365"
# 13      "ba713bce579146d3be54c4ae5e34b33d"
# 14      "f7e737d39d97e1042db0bcfd9b91a162"
# 15    "7d1badfee8173f9ca853265a12dd0256-3"
# 16      "d41d8cd98f00b204e9800998ecf8427e"
# 17      "21bae37b41c56b66973312a07322b5e4"
# 18      "c726b249410a532cce10fa166ce8616c"
# 19      "696af259d3203446b846de7937b5810c"
# 20      "3d10cad17e2279b29da00756a885659b"
# ...
